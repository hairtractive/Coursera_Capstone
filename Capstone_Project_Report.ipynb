# %% [markdown]
# # Capstone Project Report: Battle of Neighbourhoods

# %% [markdown]
# ## 1. Introduction/Business Problem

# %% [markdown]
# The goal of this project is to determine the best location to open a Japanese restaurant in Toronto.
#
# My client is an entrepreneur and a global real state investor that wants to expand one of his restaurants' chain and open a new location in the city of Toronto. Since Downtown Toronto is very competetive, my client needs insights from data to decide in which neighborhood to establish his new Japanese restaurant.

# %% [markdown]
# ### Audience

# %% [markdown]
# This report provides valuable information for for investors looking to open a restaurant in Toronto, as it shows relevant insights from data that might be crucial to decide the best neighborhood to establish a new restaurant.

# %% [markdown]
# ## 2. Data

# %% [markdown]
# This project uses data from two data sources: Wikipedia, Statistics Canada (StatsCan) and Foursquare.
#
# - The Wikipedia data source, has Toronto neighborhood's details along with their postal codes. All the information is available here: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
#
# - The Statistics Canada population density dataset which provides information of population count based on the postal code of communities across the country. This data will be used to determine the locations with the highest population density, assuming that the demand for a Japanese Restaurant would be higher. This data will be analysed with Foursquare data (the data source mentioned bellow), to see where existing restaurants are. In this project, it is assumed that the places with more Japanese restaurants are likely to have the greatest demand. It will be also considered that the people that frequent these restaurants are likely within the same neighborhood or close to another neighborhood with similar population density. This dataset is available here: https://www12.statcan.gc.ca/census-recensement/2016/dp-pd/hlt-fst/pd-pl/Table.cfm?Lang=Eng&T=1201&S=22&O=A
#
#
# - The Foursquare API will be used to obtain the geographical location data for Downtown Toronto. This data will be used to explore the restaurant venues in the neighbourhoods that will be crucial in determining the number of restaurants in each neighborhood, which we can then cross with the population data from the StatsCan information above. From here, we are able to determine the best location based on existing restaurants and population density.

# %%
#Installing Folium
# !pip install folium
# Out:
# Requirement already satisfied: folium in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.25.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (1.15.0)
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.11.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium) (1.1.1)

# %%
conda install -c anaconda beautifulsoup4
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda lxml
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import folium
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
# %matplotlib inline
import json
from pandas.io.json import json_normalize

# %%
# Obtaining Wikipedia data using get request and BeautifulSoup4:
wiki_data= requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
wiki_soup= BeautifulSoup(wiki_data, 'lxml')

# %%
#Defining the dataframe columns
New_columns=['Postal Code', 'Borough', 'Neighborhood']

#Creating a new dataframe
df=pd.DataFrame(columns=New_columns)
df
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighborhood]
# Index: []

# %%
#Filling the dataframe
wiki_table=wiki_soup.find('table')
wiki_table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Postal Code
# </th>
# <th>Borough
# </th>
# <th>Neighbourhood
# </th></tr>
# <tr>
# <td>M1A
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M2A
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3A
# </td>
# <td>North York
# </td>
# <td>Parkwoods
# </td></tr>
# <tr>
# <td>M4A
# </td>
# <td>North York
# </td>
# <td>Victoria Village
# </td></tr>
# <tr>
# <td>M5A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Regent Park, Harbourfront
# </td></tr>
# <tr>
# <td>M6A
# </td>
# <td>North York
# </td>
# <td>Lawrence Manor, Lawrence Heights
# </td></tr>
# <tr>
# <td>M7A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Queen's Park, Ontario Provincial Government
# </td></tr>
# <tr>
# <td>M8A
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9A
# </td>
# <td>Etobicoke
# </td>
# <td>Islington Avenue, Humber Valley Village
# </td></tr>
# <tr>
# <td>M1B
# </td>
# <td>Scarborough
# </td>
# <td>Malvern, Rouge
# </td></tr>
# <tr>
# <td>M2B
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3B
# </td>
# <td>North York
# </td>
# <td>Don Mills
# </td></tr>
# <tr>
# <td>M4B
# </td>
# <td>East York
# </td>
# <td>Parkview Hill, Woodbine Gardens
# </td></tr>
# <tr>
# <td>M5B
# </td>
# <td>Downtown Toronto
# </td>
# <td>Garden District, Ryerson
# </td></tr>
# <tr>
# <td>M6B
# </td>
# <td>North York
# </td>
# <td>Glencairn
# </td></tr>
# <tr>
# <td>M7B
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8B
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9B
# </td>
# <td>Etobicoke
# </td>
# <td>West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# </td></tr>
# <tr>
# <td>M1C
# </td>
# <td>Scarborough
# </td>
# <td>Rouge Hill, Port Union, Highland Creek
# </td></tr>
# <tr>
# <td>M2C
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3C
# </td>
# <td>North York
# </td>
# <td>Don Mills
# </td></tr>
# <tr>
# <td>M4C
# </td>
# <td>East York
# </td>
# <td>Woodbine Heights
# </td></tr>
# <tr>
# <td>M5C
# </td>
# <td>Downtown Toronto
# </td>
# <td>St. James Town
# </td></tr>
# <tr>
# <td>M6C
# </td>
# <td>York
# </td>
# <td>Humewood-Cedarvale
# </td></tr>
# <tr>
# <td>M7C
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8C
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9C
# </td>
# <td>Etobicoke
# </td>
# <td>Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# </td></tr>
# <tr>
# <td>M1E
# </td>
# <td>Scarborough
# </td>
# <td>Guildwood, Morningside, West Hill
# </td></tr>
# <tr>
# <td>M2E
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3E
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4E
# </td>
# <td>East Toronto
# </td>
# <td>The Beaches
# </td></tr>
# <tr>
# <td>M5E
# </td>
# <td>Downtown Toronto
# </td>
# <td>Berczy Park
# </td></tr>
# <tr>
# <td>M6E
# </td>
# <td>York
# </td>
# <td>Caledonia-Fairbanks
# </td></tr>
# <tr>
# <td>M7E
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8E
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9E
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1G
# </td>
# <td>Scarborough
# </td>
# <td>Woburn
# </td></tr>
# <tr>
# <td>M2G
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3G
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4G
# </td>
# <td>East York
# </td>
# <td>Leaside
# </td></tr>
# <tr>
# <td>M5G
# </td>
# <td>Downtown Toronto
# </td>
# <td>Central Bay Street
# </td></tr>
# <tr>
# <td>M6G
# </td>
# <td>Downtown Toronto
# </td>
# <td>Christie
# </td></tr>
# <tr>
# <td>M7G
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8G
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9G
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1H
# </td>
# <td>Scarborough
# </td>
# <td>Cedarbrae
# </td></tr>
# <tr>
# <td>M2H
# </td>
# <td>North York
# </td>
# <td>Hillcrest Village
# </td></tr>
# <tr>
# <td>M3H
# </td>
# <td>North York
# </td>
# <td>Bathurst Manor, Wilson Heights, Downsview North
# </td></tr>
# <tr>
# <td>M4H
# </td>
# <td>East York
# </td>
# <td>Thorncliffe Park
# </td></tr>
# <tr>
# <td>M5H
# </td>
# <td>Downtown Toronto
# </td>
# <td>Richmond, Adelaide, King
# </td></tr>
# <tr>
# <td>M6H
# </td>
# <td>West Toronto
# </td>
# <td>Dufferin, Dovercourt Village
# </td></tr>
# <tr>
# <td>M7H
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8H
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9H
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1J
# </td>
# <td>Scarborough
# </td>
# <td>Scarborough Village
# </td></tr>
# <tr>
# <td>M2J
# </td>
# <td>North York
# </td>
# <td>Fairview, Henry Farm, Oriole
# </td></tr>
# <tr>
# <td>M3J
# </td>
# <td>North York
# </td>
# <td>Northwood Park, York University
# </td></tr>
# <tr>
# <td>M4J
# </td>
# <td>East York
# </td>
# <td>East Toronto, Broadview North (Old East York)
# </td></tr>
# <tr>
# <td>M5J
# </td>
# <td>Downtown Toronto
# </td>
# <td>Harbourfront East, Union Station, Toronto Islands
# </td></tr>
# <tr>
# <td>M6J
# </td>
# <td>West Toronto
# </td>
# <td>Little Portugal, Trinity
# </td></tr>
# <tr>
# <td>M7J
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8J
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9J
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1K
# </td>
# <td>Scarborough
# </td>
# <td>Kennedy Park, Ionview, East Birchmount Park
# </td></tr>
# <tr>
# <td>M2K
# </td>
# <td>North York
# </td>
# <td>Bayview Village
# </td></tr>
# <tr>
# <td>M3K
# </td>
# <td>North York
# </td>
# <td>Downsview
# </td></tr>
# <tr>
# <td>M4K
# </td>
# <td>East Toronto
# </td>
# <td>The Danforth West, Riverdale
# </td></tr>
# <tr>
# <td>M5K
# </td>
# <td>Downtown Toronto
# </td>
# <td>Toronto Dominion Centre, Design Exchange
# </td></tr>
# <tr>
# <td>M6K
# </td>
# <td>West Toronto
# </td>
# <td>Brockton, Parkdale Village, Exhibition Place
# </td></tr>
# <tr>
# <td>M7K
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8K
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9K
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1L
# </td>
# <td>Scarborough
# </td>
# <td>Golden Mile, Clairlea, Oakridge
# </td></tr>
# <tr>
# <td>M2L
# </td>
# <td>North York
# </td>
# <td>York Mills, Silver Hills
# </td></tr>
# <tr>
# <td>M3L
# </td>
# <td>North York
# </td>
# <td>Downsview
# </td></tr>
# <tr>
# <td>M4L
# </td>
# <td>East Toronto
# </td>
# <td>India Bazaar, The Beaches West
# </td></tr>
# <tr>
# <td>M5L
# </td>
# <td>Downtown Toronto
# </td>
# <td>Commerce Court, Victoria Hotel
# </td></tr>
# <tr>
# <td>M6L
# </td>
# <td>North York
# </td>
# <td>North Park, Maple Leaf Park, Upwood Park
# </td></tr>
# <tr>
# <td>M7L
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8L
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9L
# </td>
# <td>North York
# </td>
# <td>Humber Summit
# </td></tr>
# <tr>
# <td>M1M
# </td>
# <td>Scarborough
# </td>
# <td>Cliffside, Cliffcrest, Scarborough Village West
# </td></tr>
# <tr>
# <td>M2M
# </td>
# <td>North York
# </td>
# <td>Willowdale, Newtonbrook
# </td></tr>
# <tr>
# <td>M3M
# </td>
# <td>North York
# </td>
# <td>Downsview
# </td></tr>
# <tr>
# <td>M4M
# </td>
# <td>East Toronto
# </td>
# <td>Studio District
# </td></tr>
# <tr>
# <td>M5M
# </td>
# <td>North York
# </td>
# <td>Bedford Park, Lawrence Manor East
# </td></tr>
# <tr>
# <td>M6M
# </td>
# <td>York
# </td>
# <td>Del Ray, Mount Dennis, Keelsdale and Silverthorn
# </td></tr>
# <tr>
# <td>M7M
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8M
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9M
# </td>
# <td>North York
# </td>
# <td>Humberlea, Emery
# </td></tr>
# <tr>
# <td>M1N
# </td>
# <td>Scarborough
# </td>
# <td>Birch Cliff, Cliffside West
# </td></tr>
# <tr>
# <td>M2N
# </td>
# <td>North York
# </td>
# <td>Willowdale, Willowdale East
# </td></tr>
# <tr>
# <td>M3N
# </td>
# <td>North York
# </td>
# <td>Downsview
# </td></tr>
# <tr>
# <td>M4N
# </td>
# <td>Central Toronto
# </td>
# <td>Lawrence Park
# </td></tr>
# <tr>
# <td>M5N
# </td>
# <td>Central Toronto
# </td>
# <td>Roselawn
# </td></tr>
# <tr>
# <td>M6N
# </td>
# <td>York
# </td>
# <td>Runnymede, The Junction North
# </td></tr>
# <tr>
# <td>M7N
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8N
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9N
# </td>
# <td>York
# </td>
# <td>Weston
# </td></tr>
# <tr>
# <td>M1P
# </td>
# <td>Scarborough
# </td>
# <td>Dorset Park, Wexford Heights, Scarborough Town Centre
# </td></tr>
# <tr>
# <td>M2P
# </td>
# <td>North York
# </td>
# <td>York Mills West
# </td></tr>
# <tr>
# <td>M3P
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4P
# </td>
# <td>Central Toronto
# </td>
# <td>Davisville North
# </td></tr>
# <tr>
# <td>M5P
# </td>
# <td>Central Toronto
# </td>
# <td>Forest Hill North &amp; West, Forest Hill Road Park
# </td></tr>
# <tr>
# <td>M6P
# </td>
# <td>West Toronto
# </td>
# <td>High Park, The Junction South
# </td></tr>
# <tr>
# <td>M7P
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8P
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9P
# </td>
# <td>Etobicoke
# </td>
# <td>Westmount
# </td></tr>
# <tr>
# <td>M1R
# </td>
# <td>Scarborough
# </td>
# <td>Wexford, Maryvale
# </td></tr>
# <tr>
# <td>M2R
# </td>
# <td>North York
# </td>
# <td>Willowdale, Willowdale West
# </td></tr>
# <tr>
# <td>M3R
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4R
# </td>
# <td>Central Toronto
# </td>
# <td>North Toronto West,  Lawrence Park
# </td></tr>
# <tr>
# <td>M5R
# </td>
# <td>Central Toronto
# </td>
# <td>The Annex, North Midtown, Yorkville
# </td></tr>
# <tr>
# <td>M6R
# </td>
# <td>West Toronto
# </td>
# <td>Parkdale, Roncesvalles
# </td></tr>
# <tr>
# <td>M7R
# </td>
# <td>Mississauga
# </td>
# <td>Canada Post Gateway Processing Centre
# </td></tr>
# <tr>
# <td>M8R
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9R
# </td>
# <td>Etobicoke
# </td>
# <td>Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# </td></tr>
# <tr>
# <td>M1S
# </td>
# <td>Scarborough
# </td>
# <td>Agincourt
# </td></tr>
# <tr>
# <td>M2S
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3S
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4S
# </td>
# <td>Central Toronto
# </td>
# <td>Davisville
# </td></tr>
# <tr>
# <td>M5S
# </td>
# <td>Downtown Toronto
# </td>
# <td>University of Toronto, Harbord
# </td></tr>
# <tr>
# <td>M6S
# </td>
# <td>West Toronto
# </td>
# <td>Runnymede, Swansea
# </td></tr>
# <tr>
# <td>M7S
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8S
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9S
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1T
# </td>
# <td>Scarborough
# </td>
# <td>Clarks Corners, Tam O'Shanter, Sullivan
# </td></tr>
# <tr>
# <td>M2T
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3T
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4T
# </td>
# <td>Central Toronto
# </td>
# <td>Moore Park, Summerhill East
# </td></tr>
# <tr>
# <td>M5T
# </td>
# <td>Downtown Toronto
# </td>
# <td>Kensington Market, Chinatown, Grange Park
# </td></tr>
# <tr>
# <td>M6T
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7T
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8T
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9T
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1V
# </td>
# <td>Scarborough
# </td>
# <td>Milliken, Agincourt North, Steeles East, L'Amoreaux East
# </td></tr>
# <tr>
# <td>M2V
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3V
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4V
# </td>
# <td>Central Toronto
# </td>
# <td>Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# </td></tr>
# <tr>
# <td>M5V
# </td>
# <td>Downtown Toronto
# </td>
# <td>CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# </td></tr>
# <tr>
# <td>M6V
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7V
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8V
# </td>
# <td>Etobicoke
# </td>
# <td>New Toronto, Mimico South, Humber Bay Shores
# </td></tr>
# <tr>
# <td>M9V
# </td>
# <td>Etobicoke
# </td>
# <td>South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# </td></tr>
# <tr>
# <td>M1W
# </td>
# <td>Scarborough
# </td>
# <td>Steeles West, L'Amoreaux West
# </td></tr>
# <tr>
# <td>M2W
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3W
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4W
# </td>
# <td>Downtown Toronto
# </td>
# <td>Rosedale
# </td></tr>
# <tr>
# <td>M5W
# </td>
# <td>Downtown Toronto
# </td>
# <td>Stn A PO Boxes
# </td></tr>
# <tr>
# <td>M6W
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7W
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8W
# </td>
# <td>Etobicoke
# </td>
# <td>Alderwood, Long Branch
# </td></tr>
# <tr>
# <td>M9W
# </td>
# <td>Etobicoke
# </td>
# <td>Northwest, West Humber - Clairville
# </td></tr>
# <tr>
# <td>M1X
# </td>
# <td>Scarborough
# </td>
# <td>Upper Rouge
# </td></tr>
# <tr>
# <td>M2X
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3X
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4X
# </td>
# <td>Downtown Toronto
# </td>
# <td>St. James Town, Cabbagetown
# </td></tr>
# <tr>
# <td>M5X
# </td>
# <td>Downtown Toronto
# </td>
# <td>First Canadian Place, Underground city
# </td></tr>
# <tr>
# <td>M6X
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7X
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8X
# </td>
# <td>Etobicoke
# </td>
# <td>The Kingsway, Montgomery Road, Old Mill North
# </td></tr>
# <tr>
# <td>M9X
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1Y
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M2Y
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3Y
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4Y
# </td>
# <td>Downtown Toronto
# </td>
# <td>Church and Wellesley
# </td></tr>
# <tr>
# <td>M5Y
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M6Y
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7Y
# </td>
# <td>East Toronto
# </td>
# <td>Business reply mail Processing Centre, South Central Letter Processing Plant Toronto
# </td></tr>
# <tr>
# <td>M8Y
# </td>
# <td>Etobicoke
# </td>
# <td>Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# </td></tr>
# <tr>
# <td>M9Y
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1Z
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M2Z
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3Z
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4Z
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M5Z
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M6Z
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7Z
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8Z
# </td>
# <td>Etobicoke
# </td>
# <td>Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West
# </td></tr>
# <tr>
# <td>M9Z
# </td>
# <td>Not assigned
# </td>
# <td>Not assigned
# </td></tr></tbody></table>

# %%
# Looping through the table and filling the dataframe one row at a time
for tr in wiki_table.find_all('tr'):
    new_row=[]
    for td in tr.find_all('td'):
        new_row.append(td.text.strip())
    if len(new_row)==3:
            df.loc[len(df)]=new_row
df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
# Processing cells that have assigned borough
df_new= df[df.Borough!='Not assigned']
df_new.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# Creating the resultant dataframe
df_new = df_new.groupby('Postal Code').agg({'Borough':'first','Neighborhood': ', '.join}).reset_index()
df_new
# Out:
#     Postal Code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                           Neighborhood
# 0                       Malvern, Rouge, Malvern, Rouge
# 1    Rouge Hill, Port Union, Highland Creek, Rouge ...
# 2    Guildwood, Morningside, West Hill, Guildwood, ...
# 3                                       Woburn, Woburn
# 4                                 Cedarbrae, Cedarbrae
# ..                                                 ...
# 98                                      Weston, Weston
# 99                                Westmount, Westmount
# 100  Kingsview Village, St. Phillips, Martin Grove ...
# 101  South Steeles, Silverstone, Humbergate, Jamest...
# 102  Northwest, West Humber - Clairville, Northwest...
#
# [103 rows x 3 columns]

# %%
#Creating the dataframe coordinates from the data
df_coor=pd.read_csv('http://cocl.us/Geospatial_data')
df_coor.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#Combining neighborhood dataset with coordinates dataset
df_new=pd.merge(df_new, df_coor, on='Postal Code')
df_new.head(103)
# Out:
#     Postal Code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                       Malvern, Rouge, Malvern, Rouge  43.806686 -79.194353
# 1    Rouge Hill, Port Union, Highland Creek, Rouge ...  43.784535 -79.160497
# 2    Guildwood, Morningside, West Hill, Guildwood, ...  43.763573 -79.188711
# 3                                       Woburn, Woburn  43.770992 -79.216917
# 4                                 Cedarbrae, Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 98                                      Weston, Weston  43.706876 -79.518188
# 99                                Westmount, Westmount  43.696319 -79.532242
# 100  Kingsview Village, St. Phillips, Martin Grove ...  43.688905 -79.554724
# 101  South Steeles, Silverstone, Humbergate, Jamest...  43.739416 -79.588437
# 102  Northwest, West Humber - Clairville, Northwest...  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
#Reading the data into a pandas dataframe
df_pop = pd.read_csv('T120120210223044745.CSV',encoding = 'unicode_escape')

# Remove unnecessary data from the table
df_pop = df_pop.rename(columns={'Geographic code':'Postal Code', 'Geographic name':'Geoname', 'Province or territory':'Province', 'Incompletely enumerated Indian reserves and Indian settlements, 2016':'Incomplete', 'Population, 2016':'Population2016', 'Total private dwellings, 2016':'PrivateDwellings', 'Private dwellings occupied by usual residents, 2016':'OccupiedPrivateDwellings'})
df_pop = df_pop.drop(columns=['Geoname', 'Province', 'Incomplete', 'PrivateDwellings', 'OccupiedPrivateDwellings'])
df_pop = df_pop.iloc[1:]

df_pop.info
# Out:
# <bound method DataFrame.info of                                             Postal Code  Population2016
# 1                                                   A0A         46587.0
# 2                                                   A0B         19792.0
# 3                                                   A0C         12587.0
# 4                                                   A0E         22294.0
# 5                                                   A0G         35266.0
# ...                                                 ...             ...
# 1644  For further information, refer to: http://www1...             NaN
# 1645  Source: Statistics Canada, 2016 Census of Popu...             NaN
# 1646  How to cite: Statistics Canada. 2017. Populati...             NaN
# 1647  Statistics Canada Catalogue no. 98-402-X201600...             NaN
# 1648  http://www12.statcan.gc.ca/census-recensement/...             NaN
#
# [1648 rows x 2 columns]>

# %%
#remove the last rows from the dataset since it has irrelevant information
df_pop.dropna(subset = ["Population2016"], inplace=True)
df_pop.tail()
# Out:
#      Postal Code  Population2016
# 1637         X0G           500.0
# 1638         X1A         20054.0
# 1639         Y0A          1641.0
# 1640         Y0B          6561.0
# 1641         Y1A         27672.0

# %%
# Combining data from both datasets and Creating a new dataframe with Toronto neighbourhoods sorted by population

df3 = pd.merge(df_pop, df_new, on="Postal Code", how='right')
df3 = df3.sort_values(by=['Population2016'], ascending=False)
df3.dropna(subset = ["Population2016"], inplace=True)
df3.head()
# Out:
#     Postal Code  Population2016      Borough  \
# 22          M2N         75897.0   North York
# 0           M1B         66108.0  Scarborough
# 18          M2J         58293.0   North York
# 101         M9V         55959.0    Etobicoke
# 14          M1V         54680.0  Scarborough
#
#                                           Neighborhood   Latitude  Longitude
# 22   Willowdale, Willowdale East, Willowdale, Willo...  43.770120 -79.408493
# 0                       Malvern, Rouge, Malvern, Rouge  43.806686 -79.194353
# 18   Fairview, Henry Farm, Oriole, Fairview, Henry ...  43.778517 -79.346556
# 101  South Steeles, Silverstone, Humbergate, Jamest...  43.739416 -79.588437
# 14   Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577

# %%
#Defining Foursquare credentials and version
CLIENT_ID = 'XH32H40ZP2MRUPOYX3HYYFQYWRUVPDTPIJBRFU1G3Q2V2RLH' 
CLIENT_SECRET = 'QWADZD1OW1Y5VLJDBJ4HVVSSZWTTZKNQ5NHVOSPVZRYQIJP1' 
ACCESS_TOKEN = 'MC0DCSLO2L4N4Z5P1AM0CFQQ5EGYF003DPQYFDTLYS1KMWLL' 
VERSION = '20180604'

# %%
# Setting a limit to prevent Foursquare's free account overuse

limit = 200

# Setting a search radius of 5000m (assuming that people will travel up to 5km to visit a restaurant)

radius = 5000

# Defining a function to retrieve venues

def getNearbyVenues(names, latitudes, longitudes, radius=5000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit)
            
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# Getting neighbourhood's list

Toronto_Venues = getNearbyVenues(names=df3['Neighborhood'],
                                   latitudes=df3['Latitude'],
                                   longitudes=df3['Longitude']
                                  )
# Out:
# Willowdale, Willowdale East, Willowdale, Willowdale East
# Malvern, Rouge, Malvern, Rouge
# Fairview, Henry Farm, Oriole, Fairview, Henry Farm, Oriole
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens, South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Milliken, Agincourt North, Steeles East, L'Amoreaux East, Milliken, Agincourt North, Steeles East, L'Amoreaux East
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport, CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Steeles West, L'Amoreaux West, Steeles West, L'Amoreaux West
# Kennedy Park, Ionview, East Birchmount Park, Kennedy Park, Ionview, East Birchmount Park
# Guildwood, Morningside, West Hill, Guildwood, Morningside, West Hill
# Woodbine Heights, Woodbine Heights
# Dorset Park, Wexford Heights, Scarborough Town Centre, Dorset Park, Wexford Heights, Scarborough Town Centre
# Dufferin, Dovercourt Village, Dufferin, Dovercourt Village
# Del Ray, Mount Dennis, Keelsdale and Silverthorn, Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Downsview, Downsview
# Runnymede, The Junction North, Runnymede, The Junction North
# Regent Park, Harbourfront, Regent Park, Harbourfront
# Brockton, Parkdale Village, Exhibition Place, Brockton, Parkdale Village, Exhibition Place
# Willowdale, Willowdale West, Willowdale, Willowdale West
# Northwest, West Humber - Clairville, Northwest, West Humber - Clairville
# High Park, The Junction South, High Park, The Junction South
# Don Mills, Don Mills
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood, Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Caledonia-Fairbanks, Caledonia-Fairbanks
# New Toronto, Mimico South, Humber Bay Shores, New Toronto, Mimico South, Humber Bay Shores
# Agincourt, Agincourt
# Bathurst Manor, Wilson Heights, Downsview North, Bathurst Manor, Wilson Heights, Downsview North
# Scarborough Village, Scarborough Village
# East Toronto, Broadview North (Old East York), East Toronto, Broadview North (Old East York)
# Rouge Hill, Port Union, Highland Creek, Rouge Hill, Port Union, Highland Creek
# Islington Avenue, Humber Valley Village, Islington Avenue, Humber Valley Village
# Golden Mile, Clairlea, Oakridge, Golden Mile, Clairlea, Oakridge
# Parkwoods, Parkwoods
# Clarks Corners, Tam O'Shanter, Sullivan, Clarks Corners, Tam O'Shanter, Sullivan
# Runnymede, Swansea, Runnymede, Swansea
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens, Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# Little Portugal, Trinity, Little Portugal, Trinity
# India Bazaar, The Beaches West, India Bazaar, The Beaches West
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale, West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Willowdale, Newtonbrook, Willowdale, Newtonbrook
# Christie, Christie
# The Danforth West, Riverdale, The Danforth West, Riverdale
# Church and Wellesley, Church and Wellesley
# Wexford, Maryvale, Wexford, Maryvale
# Woburn, Woburn
# Glencairn, Glencairn
# Davisville, Davisville
# The Annex, North Midtown, Yorkville, The Annex, North Midtown, Yorkville
# Bedford Park, Lawrence Manor East, Bedford Park, Lawrence Manor East
# Northwood Park, York University, Northwood Park, York University
# Weston, Weston
# The Beaches, The Beaches
# Studio District, Studio District
# Humewood-Cedarvale, Humewood-Cedarvale
# Hillcrest Village, Hillcrest Village
# Cedarbrae, Cedarbrae
# Downsview, Downsview
# Bayview Village, Bayview Village
# Cliffside, Cliffcrest, Scarborough Village West, Cliffside, Cliffcrest, Scarborough Village West
# Humberlea, Emery, Humberlea, Emery
# Birch Cliff, Cliffside West, Birch Cliff, Cliffside West
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East, Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Lawrence Manor, Lawrence Heights, Lawrence Manor, Lawrence Heights
# Westmount, Westmount
# St. James Town, Cabbagetown, St. James Town, Cabbagetown
# Alderwood, Long Branch, Alderwood, Long Branch
# North Park, Maple Leaf Park, Upwood Park, North Park, Maple Leaf Park, Upwood Park
# Davisville North, Davisville North
# Parkdale, Roncesvalles, Parkdale, Roncesvalles
# Thorncliffe Park, Thorncliffe Park
# Forest Hill North & West, Forest Hill Road Park, Forest Hill North & West, Forest Hill Road Park
# Leaside, Leaside
# Parkview Hill, Woodbine Gardens, Parkview Hill, Woodbine Gardens
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park, Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Kensington Market, Chinatown, Grange Park, Kensington Market, Chinatown, Grange Park
# Downsview, Downsview
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West, Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West
# Roselawn, Roselawn
# University of Toronto, Harbord, University of Toronto, Harbord
# Lawrence Park, Lawrence Park
# Upper Rouge, Upper Rouge
# Rosedale, Rosedale
# Harbourfront East, Union Station, Toronto Islands, Harbourfront East, Union Station, Toronto Islands
# Victoria Village, Victoria Village
# Don Mills, Don Mills
# Garden District, Ryerson, Garden District, Ryerson
# Humber Summit, Humber Summit
# York Mills, Silver Hills, York Mills, Silver Hills
# North Toronto West,  Lawrence Park, North Toronto West,  Lawrence Park
# The Kingsway, Montgomery Road, Old Mill North, The Kingsway, Montgomery Road, Old Mill North
# Moore Park, Summerhill East, Moore Park, Summerhill East
# Berczy Park, Berczy Park
# Central Bay Street, Central Bay Street
# York Mills West, York Mills West
# Downsview, Downsview
# St. James Town, St. James Town
# Richmond, Adelaide, King, Richmond, Adelaide, King
# Stn A PO Boxes, Stn A PO Boxes
# First Canadian Place, Underground city, First Canadian Place, Underground city
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto, Business reply mail Processing Centre, South Central Letter Processing Plant Toronto
# Queen's Park, Ontario Provincial Government, Queen's Park, Ontario Provincial Government
# Commerce Court, Victoria Hotel, Commerce Court, Victoria Hotel
# Toronto Dominion Centre, Design Exchange, Toronto Dominion Centre, Design Exchange

# %%
# SHOW UNIQUE VENUE CATEGORIES

print('Unique Venue Categories:')
list(Toronto_Venues['Venue Category'].unique())
# Out:
# Unique Venue Categories:
# ['Hotel',
#  'Ramen Restaurant',
#  'Seafood Restaurant',
#  'Steakhouse',
#  'Japanese Restaurant',
#  'Café',
#  'Bubble Tea Shop',
#  'Movie Theater',
#  'Creperie',
#  'Grocery Store',
#  'Fried Chicken Joint',
#  'Sushi Restaurant',
#  'Liquor Store',
#  'Korean Restaurant',
#  'Coffee Shop',
#  'Burger Joint',
#  'Bakery',
#  'Thai Restaurant',
#  'Theater',
#  'Park',
#  'French Restaurant',
#  'Supermarket',
#  'Plaza',
#  'Bridal Shop',
#  'Gym',
#  'Pizza Place',
#  'Spa',
#  'Fast Food Restaurant',
#  'Shopping Mall',
#  'Ski Chalet',
#  'Middle Eastern Restaurant',
#  'General Entertainment',
#  'Health Food Store',
#  'Fish Market',
#  'Mediterranean Restaurant',
#  'Bookstore',
#  'Persian Restaurant',
#  'Greek Restaurant',
#  'Deli / Bodega',
#  'Clothing Store',
#  'Restaurant',
#  'Outdoor Supply Store',
#  'Vietnamese Restaurant',
#  'Sandwich Place',
#  'Sporting Goods Shop',
#  'Dessert Shop',
#  'Tea Room',
#  'Italian Restaurant',
#  'Gourmet Shop',
#  'Escape Room',
#  'Cosmetics Shop',
#  'Auto Dealership',
#  'Furniture / Home Store',
#  'Trail',
#  'Hobby Shop',
#  'Bagel Shop',
#  'Breakfast Spot',
#  'Chinese Restaurant',
#  'Athletics & Sports',
#  'Zoo Exhibit',
#  'Zoo',
#  'Caribbean Restaurant',
#  'Campground',
#  'National Park',
#  'Food & Drink Shop',
#  'Neighborhood',
#  'Pharmacy',
#  'Sri Lankan Restaurant',
#  'Bank',
#  'Chocolate Shop',
#  'Music Store',
#  'Skating Rink',
#  'Smoothie Shop',
#  'Ice Cream Shop',
#  'Paper / Office Supplies Store',
#  'Pub',
#  'Gas Station',
#  'Discount Store',
#  'Mexican Restaurant',
#  'Juice Bar',
#  'Beer Store',
#  'Indian Restaurant',
#  'American Restaurant',
#  'Diner',
#  'Event Space',
#  'Electronics Store',
#  'Burrito Place',
#  'Falafel Restaurant',
#  'Golf Course',
#  'Shopping Plaza',
#  'Health & Beauty Service',
#  'New American Restaurant',
#  'Cantonese Restaurant',
#  'BBQ Joint',
#  'Gym / Fitness Center',
#  'Pool Hall',
#  "Women's Store",
#  'Garden',
#  'Fish & Chips Shop',
#  'Asian Restaurant',
#  'Music Venue',
#  'Racecourse',
#  'Frozen Yogurt Shop',
#  'Food Court',
#  'Convenience Store',
#  'Noodle House',
#  'Vegetarian / Vegan Restaurant',
#  'Tattoo Parlor',
#  'Hakka Restaurant',
#  'Optical Shop',
#  'Snack Place',
#  'Hotpot Restaurant',
#  'Dumpling Restaurant',
#  'Arts & Crafts Store',
#  'Sports Club',
#  'Automotive Shop',
#  'Portuguese Restaurant',
#  'Flower Shop',
#  'Performing Arts Venue',
#  'Monument / Landmark',
#  'Lake',
#  'Baseball Stadium',
#  'Soccer Stadium',
#  'Butcher',
#  'Record Shop',
#  'Street Art',
#  'Museum',
#  'Cocktail Bar',
#  'Farmers Market',
#  'Food Truck',
#  'Brewery',
#  'Organic Grocery',
#  'Gastropub',
#  'Scenic Lookout',
#  'Hostel',
#  'Beach',
#  'Tapas Restaurant',
#  'Doner Restaurant',
#  'Theme Park',
#  'Bar',
#  'Historic Site',
#  'Latin American Restaurant',
#  'Circus',
#  'Dog Run',
#  'Concert Hall',
#  'Dance Studio',
#  'Food',
#  'Pet Store',
#  'Filipino Restaurant',
#  'Turkish Restaurant',
#  'Warehouse Store',
#  'Xinjiang Restaurant',
#  'African Restaurant',
#  'Sports Bar',
#  'Rock Climbing Spot',
#  'Department Store',
#  'Bistro',
#  'Video Game Store',
#  'Yoga Studio',
#  'Ethiopian Restaurant',
#  'Pastry Shop',
#  'Playground',
#  'Hungarian Restaurant',
#  'Soccer Field',
#  'Beer Bar',
#  'Afghan Restaurant',
#  'Egyptian Restaurant',
#  'Donut Shop',
#  'Comic Shop',
#  'History Museum',
#  'Indie Movie Theater',
#  'Pakistani Restaurant',
#  'Toy / Game Store',
#  'Cupcake Shop',
#  'South American Restaurant',
#  'Soup Place',
#  'Cuban Restaurant',
#  'Boutique',
#  'Field',
#  'Eastern European Restaurant',
#  'Tibetan Restaurant',
#  'Bike Shop',
#  'Massage Studio',
#  'Tennis Stadium',
#  'Recreation Center',
#  'Climbing Gym',
#  'Hockey Arena',
#  'Wings Joint',
#  'Racetrack',
#  'Airport',
#  'Track',
#  'Construction & Landscaping',
#  'Other Nightlife',
#  'Caucasian Restaurant',
#  'Taco Place',
#  'Shoe Store',
#  'Bridge',
#  'Pool',
#  'Botanical Garden',
#  'Bath House',
#  'Basketball Court',
#  'Train Station',
#  'Nightclub',
#  'Airport Lounge',
#  'Rental Car Location',
#  'Shoe Repair',
#  'Poutine Place',
#  'Amphitheater',
#  'Other Great Outdoors',
#  'Wine Bar',
#  'Salad Place',
#  'College Rec Center',
#  'Kebab Restaurant',
#  'Comfort Food Restaurant',
#  'Kitchen Supply Store',
#  'Jewelry Store',
#  "Men's Store",
#  'Flea Market',
#  'Tram Station',
#  'Gift Shop',
#  'Hookah Bar',
#  'Art Gallery',
#  'Nail Salon',
#  'German Restaurant',
#  'Baseball Field',
#  'Szechuan Restaurant',
#  'Fruit & Vegetable Store',
#  'Cheese Shop',
#  'Intersection',
#  'Castle',
#  'Cemetery',
#  'Thrift / Vintage Store',
#  'Indonesian Restaurant',
#  'Smoke Shop',
#  'Baby Store',
#  'Big Box Store',
#  'Bowling Alley',
#  'Hardware Store',
#  'Salon / Barbershop',
#  'Badminton Court',
#  'Metro Station',
#  'Miscellaneous Shop',
#  'Brazilian Restaurant',
#  'Lingerie Store',
#  'Farm',
#  'Indian Chinese Restaurant',
#  'Buffet',
#  'Harbor / Marina',
#  'Laser Tag',
#  'Science Museum']

# %%
# ISOLATE ONLY THOSE CATEGORIES WITH JAPANESE THEMES (SUSHI, RAMEN, ETC.)
Japanese_restaurants = ['Ramen Restaurant', 'Japanese Restaurant', 'Sushi Restaurant', 'Noodle House']

Japanese_rest_pd = pd.DataFrame(Japanese_restaurants)

Japanese_rest_pd
# Out:
#                      0
# 0     Ramen Restaurant
# 1  Japanese Restaurant
# 2     Sushi Restaurant
# 3         Noodle House

# %%
# Renaming columns to the five types of Japanese restaurant
Japanese_rest_pd = Japanese_rest_pd.rename(columns={0:'Venue Category'})

# Combining dataframes to see Japanese restaurant types in neighbourhoods
Toronto_Japanese_rest = pd.merge(Toronto_Venues, Japanese_rest_pd, on='Venue Category', how='right')

Toronto_Japanese_rest
# Out:
#                                           Neighborhood  Neighborhood Latitude  \
# 0    Willowdale, Willowdale East, Willowdale, Willo...              43.770120
# 1    Willowdale, Willowdale West, Willowdale, Willo...              43.782736
# 2                                 Don Mills, Don Mills              43.725900
# 3    Bathurst Manor, Wilson Heights, Downsview Nort...              43.754328
# 4     Willowdale, Newtonbrook, Willowdale, Newtonbrook              43.789053
# ..                                                 ...                    ...
# 265  Clarks Corners, Tam O'Shanter, Sullivan, Clark...              43.781638
# 266  Clarks Corners, Tam O'Shanter, Sullivan, Clark...              43.781638
# 267               Wexford, Maryvale, Wexford, Maryvale              43.750072
# 268                                     Woburn, Woburn              43.770992
# 269                               Cedarbrae, Cedarbrae              43.773136
#
#      Neighborhood Longitude                          Venue  Venue Latitude  \
# 0                -79.408493                  Konjiki Ramen       43.766998
# 1                -79.442259                  Konjiki Ramen       43.766998
# 2                -79.340923                   Kinton Ramen       43.707302
# 3                -79.442259                  Konjiki Ramen       43.766998
# 4                -79.408493                  Konjiki Ramen       43.766998
# ..                      ...                            ...             ...
# 265              -79.304302         Wonton Chai Noodle 雲吞仔       43.787722
# 266              -79.304302  Deer Garden Signatures 鹿園魚湯米線       43.821898
# 267              -79.295849                  Eight Noodles       43.778234
# 268              -79.216917         Wonton Chai Noodle 雲吞仔       43.787722
# 269              -79.239476         Wonton Chai Noodle 雲吞仔       43.787722
#
#      Venue Longitude    Venue Category
# 0         -79.412222  Ramen Restaurant
# 1         -79.412222  Ramen Restaurant
# 2         -79.395854  Ramen Restaurant
# 3         -79.412222  Ramen Restaurant
# 4         -79.412222  Ramen Restaurant
# ..               ...               ...
# 265       -79.269552      Noodle House
# 266       -79.298857      Noodle House
# 267       -79.308299      Noodle House
# 268       -79.269552      Noodle House
# 269       -79.269552      Noodle House
#
# [270 rows x 7 columns]

# %%
# Using one hot encoding
newonehot = pd.get_dummies(Toronto_Japanese_rest[['Venue Category']], prefix="", prefix_sep="")

# Add neighbourhood back in and move to first column
newonehot['Neighborhood'] = Toronto_Japanese_rest['Neighborhood'] 
fixed_columns = [newonehot.columns[-1]] + list(newonehot.columns[:-1])
newonehot = newonehot[fixed_columns]

newonehot.head()
# Out:
#                                         Neighborhood  Japanese Restaurant  \
# 0  Willowdale, Willowdale East, Willowdale, Willo...                    0
# 1  Willowdale, Willowdale West, Willowdale, Willo...                    0
# 2                               Don Mills, Don Mills                    0
# 3  Bathurst Manor, Wilson Heights, Downsview Nort...                    0
# 4   Willowdale, Newtonbrook, Willowdale, Newtonbrook                    0
#
#    Noodle House  Ramen Restaurant  Sushi Restaurant
# 0             0                 1                 0
# 1             0                 1                 0
# 2             0                 1                 0
# 3             0                 1                 0
# 4             0                 1                 0

# %%
# Analysis of restaurant types (percentages) in each neighborhood

grouped = newonehot.groupby('Neighborhood').mean().reset_index()
grouped
# Out:
#                                          Neighborhood  Japanese Restaurant  \
# 0                                Agincourt, Agincourt             0.222222
# 1      Alderwood, Long Branch, Alderwood, Long Branch             0.500000
# 2   Bathurst Manor, Wilson Heights, Downsview Nort...             0.333333
# 3                    Bayview Village, Bayview Village             0.600000
# 4   Bedford Park, Lawrence Manor East, Bedford Par...             0.333333
# ..                                                ...                  ...
# 79  Willowdale, Willowdale East, Willowdale, Willo...             0.571429
# 80  Willowdale, Willowdale West, Willowdale, Willo...             0.400000
# 81                                     Woburn, Woburn             0.333333
# 82                   York Mills West, York Mills West             0.333333
# 83  York Mills, Silver Hills, York Mills, Silver H...             0.571429
#
#     Noodle House  Ramen Restaurant  Sushi Restaurant
# 0       0.444444          0.000000          0.333333
# 1       0.000000          0.000000          0.500000
# 2       0.000000          0.166667          0.500000
# 3       0.000000          0.200000          0.200000
# 4       0.000000          0.111111          0.555556
# ..           ...               ...               ...
# 79      0.000000          0.142857          0.285714
# 80      0.000000          0.200000          0.400000
# 81      0.333333          0.000000          0.333333
# 82      0.000000          0.111111          0.555556
# 83      0.000000          0.142857          0.285714
#
# [84 rows x 5 columns]

# %%
num_top_venues = 4

for hood in grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = grouped[grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt, Agincourt----
#                  venue  freq
# 0         Noodle House  0.44
# 1     Sushi Restaurant  0.33
# 2  Japanese Restaurant  0.22
# 3     Ramen Restaurant  0.00
#
#
# ----Alderwood, Long Branch, Alderwood, Long Branch----
#                  venue  freq
# 0  Japanese Restaurant   0.5
# 1     Sushi Restaurant   0.5
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Bathurst Manor, Wilson Heights, Downsview North, Bathurst Manor, Wilson Heights, Downsview North----
#                  venue  freq
# 0     Sushi Restaurant  0.50
# 1  Japanese Restaurant  0.33
# 2     Ramen Restaurant  0.17
# 3         Noodle House  0.00
#
#
# ----Bayview Village, Bayview Village----
#                  venue  freq
# 0  Japanese Restaurant   0.6
# 1     Ramen Restaurant   0.2
# 2     Sushi Restaurant   0.2
# 3         Noodle House   0.0
#
#
# ----Bedford Park, Lawrence Manor East, Bedford Park, Lawrence Manor East----
#                  venue  freq
# 0     Sushi Restaurant  0.56
# 1  Japanese Restaurant  0.33
# 2     Ramen Restaurant  0.11
# 3         Noodle House  0.00
#
#
# ----Berczy Park, Berczy Park----
#                  venue  freq
# 0     Ramen Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Birch Cliff, Cliffside West, Birch Cliff, Cliffside West----
#                  venue  freq
# 0  Japanese Restaurant  0.67
# 1     Sushi Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Brockton, Parkdale Village, Exhibition Place, Brockton, Parkdale Village, Exhibition Place----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto, Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Caledonia-Fairbanks, Caledonia-Fairbanks----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Cedarbrae, Cedarbrae----
#                  venue  freq
# 0  Japanese Restaurant  0.33
# 1         Noodle House  0.33
# 2     Sushi Restaurant  0.33
# 3     Ramen Restaurant  0.00
#
#
# ----Christie, Christie----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Clarks Corners, Tam O'Shanter, Sullivan, Clarks Corners, Tam O'Shanter, Sullivan----
#                  venue  freq
# 0  Japanese Restaurant  0.33
# 1         Noodle House  0.33
# 2     Sushi Restaurant  0.33
# 3     Ramen Restaurant  0.00
#
#
# ----Cliffside, Cliffcrest, Scarborough Village West, Cliffside, Cliffcrest, Scarborough Village West----
#                  venue  freq
# 0  Japanese Restaurant  0.75
# 1     Sushi Restaurant  0.25
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Commerce Court, Victoria Hotel, Commerce Court, Victoria Hotel----
#                  venue  freq
# 0     Ramen Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Davisville North, Davisville North----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Davisville, Davisville----
#                  venue  freq
# 0     Sushi Restaurant   0.6
# 1  Japanese Restaurant   0.2
# 2     Ramen Restaurant   0.2
# 3         Noodle House   0.0
#
#
# ----Del Ray, Mount Dennis, Keelsdale and Silverthorn, Del Ray, Mount Dennis, Keelsdale and Silverthorn----
#                  venue  freq
# 0  Japanese Restaurant   0.5
# 1     Sushi Restaurant   0.5
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Don Mills, Don Mills----
#                  venue  freq
# 0  Japanese Restaurant  0.86
# 1     Ramen Restaurant  0.14
# 2         Noodle House  0.00
# 3     Sushi Restaurant  0.00
#
#
# ----Dorset Park, Wexford Heights, Scarborough Town Centre, Dorset Park, Wexford Heights, Scarborough Town Centre----
#                  venue  freq
# 0         Noodle House   0.4
# 1     Sushi Restaurant   0.4
# 2  Japanese Restaurant   0.2
# 3     Ramen Restaurant   0.0
#
#
# ----Downsview, Downsview----
#                  venue  freq
# 0     Sushi Restaurant  0.56
# 1  Japanese Restaurant  0.44
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Dufferin, Dovercourt Village, Dufferin, Dovercourt Village----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----East Toronto, Broadview North (Old East York), East Toronto, Broadview North (Old East York)----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood, Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Fairview, Henry Farm, Oriole, Fairview, Henry Farm, Oriole----
#                  venue  freq
# 0  Japanese Restaurant  0.75
# 1     Sushi Restaurant  0.25
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----First Canadian Place, Underground city, First Canadian Place, Underground city----
#                  venue  freq
# 0     Ramen Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Forest Hill North & West, Forest Hill Road Park, Forest Hill North & West, Forest Hill Road Park----
#                  venue  freq
# 0     Sushi Restaurant  0.67
# 1  Japanese Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Glencairn, Glencairn----
#                  venue  freq
# 0     Sushi Restaurant  0.67
# 1  Japanese Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Golden Mile, Clairlea, Oakridge, Golden Mile, Clairlea, Oakridge----
#                  venue  freq
# 0  Japanese Restaurant  0.67
# 1     Sushi Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Harbourfront East, Union Station, Toronto Islands, Harbourfront East, Union Station, Toronto Islands----
#                  venue  freq
# 0     Ramen Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----High Park, The Junction South, High Park, The Junction South----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Hillcrest Village, Hillcrest Village----
#                  venue  freq
# 0  Japanese Restaurant  0.67
# 1     Sushi Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Humber Summit, Humber Summit----
#                  venue  freq
# 0     Sushi Restaurant  0.67
# 1  Japanese Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Humberlea, Emery, Humberlea, Emery----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Humewood-Cedarvale, Humewood-Cedarvale----
#                  venue  freq
# 0     Sushi Restaurant  0.67
# 1  Japanese Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----India Bazaar, The Beaches West, India Bazaar, The Beaches West----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Islington Avenue, Humber Valley Village, Islington Avenue, Humber Valley Village----
#                  venue  freq
# 0  Japanese Restaurant  0.67
# 1     Sushi Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Kennedy Park, Ionview, East Birchmount Park, Kennedy Park, Ionview, East Birchmount Park----
#                  venue  freq
# 0  Japanese Restaurant  0.67
# 1     Sushi Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens, Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens----
#                  venue  freq
# 0  Japanese Restaurant  0.67
# 1     Sushi Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Lawrence Manor, Lawrence Heights, Lawrence Manor, Lawrence Heights----
#                  venue  freq
# 0     Sushi Restaurant  0.67
# 1  Japanese Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Lawrence Park, Lawrence Park----
#                  venue  freq
# 0     Sushi Restaurant  0.57
# 1  Japanese Restaurant  0.29
# 2     Ramen Restaurant  0.14
# 3         Noodle House  0.00
#
#
# ----Leaside, Leaside----
#                  venue  freq
# 0     Sushi Restaurant  0.67
# 1     Ramen Restaurant  0.33
# 2  Japanese Restaurant  0.00
# 3         Noodle House  0.00
#
#
# ----Milliken, Agincourt North, Steeles East, L'Amoreaux East, Milliken, Agincourt North, Steeles East, L'Amoreaux East----
#                  venue  freq
# 0         Noodle House  0.50
# 1  Japanese Restaurant  0.25
# 2     Sushi Restaurant  0.25
# 3     Ramen Restaurant  0.00
#
#
# ----Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West, Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Moore Park, Summerhill East, Moore Park, Summerhill East----
#                  venue  freq
# 0     Ramen Restaurant   0.5
# 1     Sushi Restaurant   0.5
# 2  Japanese Restaurant   0.0
# 3         Noodle House   0.0
#
#
# ----New Toronto, Mimico South, Humber Bay Shores, New Toronto, Mimico South, Humber Bay Shores----
#                  venue  freq
# 0     Sushi Restaurant   0.8
# 1  Japanese Restaurant   0.2
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----North Park, Maple Leaf Park, Upwood Park, North Park, Maple Leaf Park, Upwood Park----
#                  venue  freq
# 0  Japanese Restaurant  0.67
# 1     Sushi Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----North Toronto West,  Lawrence Park, North Toronto West,  Lawrence Park----
#                  venue  freq
# 0  Japanese Restaurant   0.5
# 1     Sushi Restaurant   0.5
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Northwest, West Humber - Clairville, Northwest, West Humber - Clairville----
#                  venue  freq
# 0  Japanese Restaurant   0.5
# 1     Sushi Restaurant   0.5
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Northwood Park, York University, Northwood Park, York University----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East, Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Parkdale, Roncesvalles, Parkdale, Roncesvalles----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Parkview Hill, Woodbine Gardens, Parkview Hill, Woodbine Gardens----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Parkwoods, Parkwoods----
#                  venue  freq
# 0  Japanese Restaurant   0.8
# 1     Sushi Restaurant   0.2
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Richmond, Adelaide, King, Richmond, Adelaide, King----
#                  venue  freq
# 0     Ramen Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Rosedale, Rosedale----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Roselawn, Roselawn----
#                  venue  freq
# 0     Sushi Restaurant  0.67
# 1  Japanese Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Rouge Hill, Port Union, Highland Creek, Rouge Hill, Port Union, Highland Creek----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Runnymede, Swansea, Runnymede, Swansea----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Runnymede, The Junction North, Runnymede, The Junction North----
#                  venue  freq
# 0  Japanese Restaurant   0.5
# 1     Sushi Restaurant   0.5
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Scarborough Village, Scarborough Village----
#                  venue  freq
# 0  Japanese Restaurant   0.5
# 1     Sushi Restaurant   0.5
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens, South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Steeles West, L'Amoreaux West, Steeles West, L'Amoreaux West----
#                  venue  freq
# 0  Japanese Restaurant  0.38
# 1         Noodle House  0.38
# 2     Sushi Restaurant  0.25
# 3     Ramen Restaurant  0.00
#
#
# ----Stn A PO Boxes, Stn A PO Boxes----
#                  venue  freq
# 0     Ramen Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Studio District, Studio District----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park, Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                  venue  freq
# 0     Ramen Restaurant   0.5
# 1     Sushi Restaurant   0.5
# 2  Japanese Restaurant   0.0
# 3         Noodle House   0.0
#
#
# ----The Annex, North Midtown, Yorkville, The Annex, North Midtown, Yorkville----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----The Beaches, The Beaches----
#                  venue  freq
# 0  Japanese Restaurant   0.5
# 1     Sushi Restaurant   0.5
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----The Kingsway, Montgomery Road, Old Mill North, The Kingsway, Montgomery Road, Old Mill North----
#                  venue  freq
# 0     Sushi Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Thorncliffe Park, Thorncliffe Park----
#                  venue  freq
# 0     Ramen Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Toronto Dominion Centre, Design Exchange, Toronto Dominion Centre, Design Exchange----
#                  venue  freq
# 0     Ramen Restaurant   1.0
# 1  Japanese Restaurant   0.0
# 2         Noodle House   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----University of Toronto, Harbord, University of Toronto, Harbord----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Upper Rouge, Upper Rouge----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Victoria Village, Victoria Village----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale, West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale----
#                  venue  freq
# 0  Japanese Restaurant   1.0
# 1         Noodle House   0.0
# 2     Ramen Restaurant   0.0
# 3     Sushi Restaurant   0.0
#
#
# ----Westmount, Westmount----
#                  venue  freq
# 0  Japanese Restaurant  0.67
# 1     Sushi Restaurant  0.33
# 2         Noodle House  0.00
# 3     Ramen Restaurant  0.00
#
#
# ----Weston, Weston----
#                  venue  freq
# 0  Japanese Restaurant   0.5
# 1     Sushi Restaurant   0.5
# 2         Noodle House   0.0
# 3     Ramen Restaurant   0.0
#
#
# ----Wexford, Maryvale, Wexford, Maryvale----
#                  venue  freq
# 0  Japanese Restaurant   0.6
# 1         Noodle House   0.2
# 2     Sushi Restaurant   0.2
# 3     Ramen Restaurant   0.0
#
#
# ----Willowdale, Newtonbrook, Willowdale, Newtonbrook----
#                  venue  freq
# 0     Sushi Restaurant  0.57
# 1  Japanese Restaurant  0.29
# 2     Ramen Restaurant  0.14
# 3         Noodle House  0.00
#
#
# ----Willowdale, Willowdale East, Willowdale, Willowdale East----
#                  venue  freq
# 0  Japanese Restaurant  0.57
# 1     Sushi Restaurant  0.29
# 2     Ramen Restaurant  0.14
# 3         Noodle House  0.00
#
#
# ----Willowdale, Willowdale West, Willowdale, Willowdale West----
#                  venue  freq
# 0  Japanese Restaurant   0.4
# 1     Sushi Restaurant   0.4
# 2     Ramen Restaurant   0.2
# 3         Noodle House   0.0
#
#
# ----Woburn, Woburn----
#                  venue  freq
# 0  Japanese Restaurant  0.33
# 1         Noodle House  0.33
# 2     Sushi Restaurant  0.33
# 3     Ramen Restaurant  0.00
#
#
# ----York Mills West, York Mills West----
#                  venue  freq
# 0     Sushi Restaurant  0.56
# 1  Japanese Restaurant  0.33
# 2     Ramen Restaurant  0.11
# 3         Noodle House  0.00
#
#
# ----York Mills, Silver Hills, York Mills, Silver Hills----
#                  venue  freq
# 0  Japanese Restaurant  0.57
# 1     Sushi Restaurant  0.29
# 2     Ramen Restaurant  0.14
# 3         Noodle House  0.00

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
import numpy as np
num_top_venues = 4

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = grouped['Neighborhood']

for ind in np.arange(grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                               Agincourt, Agincourt          Noodle House
# 1     Alderwood, Long Branch, Alderwood, Long Branch      Sushi Restaurant
# 2  Bathurst Manor, Wilson Heights, Downsview Nort...      Sushi Restaurant
# 3                   Bayview Village, Bayview Village   Japanese Restaurant
# 4  Bedford Park, Lawrence Manor East, Bedford Par...      Sushi Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue
# 0      Sushi Restaurant   Japanese Restaurant      Ramen Restaurant
# 1   Japanese Restaurant      Ramen Restaurant          Noodle House
# 2   Japanese Restaurant      Ramen Restaurant          Noodle House
# 3      Sushi Restaurant      Ramen Restaurant          Noodle House
# 4   Japanese Restaurant      Ramen Restaurant          Noodle House

# %%
neighborhoods_venues_sorted.tail()
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 79  Willowdale, Willowdale East, Willowdale, Willo...   Japanese Restaurant
# 80  Willowdale, Willowdale West, Willowdale, Willo...      Sushi Restaurant
# 81                                     Woburn, Woburn      Sushi Restaurant
# 82                   York Mills West, York Mills West      Sushi Restaurant
# 83  York Mills, Silver Hills, York Mills, Silver H...   Japanese Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue
# 79      Sushi Restaurant      Ramen Restaurant          Noodle House
# 80   Japanese Restaurant      Ramen Restaurant          Noodle House
# 81          Noodle House   Japanese Restaurant      Ramen Restaurant
# 82   Japanese Restaurant      Ramen Restaurant          Noodle House
# 83      Sushi Restaurant      Ramen Restaurant          Noodle House

# %%
# MERGE DATAFRAMES TO INCLUDE ALL DATA FROM NEIGHBORHOOD AND RESTAURANT TYPE DFs

Toronto_complete = pd.merge(df3, neighborhoods_venues_sorted, on='Neighborhood', how='left')
Toronto_complete.dropna(subset = ["1st Most Common Venue"], inplace=True)
Toronto_complete.head()
# Out:
#   Postal Code  Population2016      Borough  \
# 0         M2N         75897.0   North York
# 2         M2J         58293.0   North York
# 3         M9V         55959.0    Etobicoke
# 4         M1V         54680.0  Scarborough
# 6         M1W         48471.0  Scarborough
#
#                                         Neighborhood   Latitude  Longitude  \
# 0  Willowdale, Willowdale East, Willowdale, Willo...  43.770120 -79.408493
# 2  Fairview, Henry Farm, Oriole, Fairview, Henry ...  43.778517 -79.346556
# 3  South Steeles, Silverstone, Humbergate, Jamest...  43.739416 -79.588437
# 4  Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 6  Steeles West, L'Amoreaux West, Steeles West, L...  43.799525 -79.318389
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0   Japanese Restaurant      Sushi Restaurant      Ramen Restaurant
# 2   Japanese Restaurant      Sushi Restaurant      Ramen Restaurant
# 3      Sushi Restaurant      Ramen Restaurant          Noodle House
# 4          Noodle House      Sushi Restaurant   Japanese Restaurant
# 6          Noodle House   Japanese Restaurant      Sushi Restaurant
#
#   4th Most Common Venue
# 0          Noodle House
# 2          Noodle House
# 3   Japanese Restaurant
# 4      Ramen Restaurant
# 6      Ramen Restaurant

# %%
# !conda install -c conda-forge scikit-learn --yes
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.12.5          |   py36h5fab9bb_1         143 KB  conda-forge
#     joblib-1.0.1               |     pyhd8ed1ab_0         206 KB  conda-forge
#     openssl-1.1.1j             |       h7f98852_0         2.1 MB  conda-forge
#     scikit-learn-0.24.1        |   py36he4fde30_0         7.5 MB  conda-forge
#     scipy-1.5.3                |   py36h9e8f40b_0        19.1 MB  conda-forge
#     threadpoolctl-2.1.0        |     pyh5ca1d4c_0          15 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        29.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             conda-forge/noarch::joblib-1.0.1-pyhd8ed1ab_0
#   scikit-learn       conda-forge/linux-64::scikit-learn-0.24.1-py36he4fde30_0
#   scipy              conda-forge/linux-64::scipy-1.5.3-py36h9e8f40b_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-2.1.0-pyh5ca1d4c_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2020.10.14-0 --> conda-forge::ca-certificates-2020.12.5-ha878542_0
#   certifi                anaconda::certifi-2020.6.20-py36_0 --> conda-forge::certifi-2020.12.5-py36h5fab9bb_1
#   openssl               anaconda::openssl-1.1.1h-h7b6447c_0 --> conda-forge::openssl-1.1.1j-h7f98852_0
#
#
#
# Downloading and Extracting Packages
# certifi-2020.12.5    | 143 KB    | ##################################### | 100%
# scipy-1.5.3          | 19.1 MB   | ##################################### | 100%
# scikit-learn-0.24.1  | 7.5 MB    | ##################################### | 100%
# openssl-1.1.1j       | 2.1 MB    | ##################################### | 100%
# joblib-1.0.1         | 206 KB    | ##################################### | 100%
# threadpoolctl-2.1.0  | 15 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# CLUSTER MODELLING
# USE SILHOUETTE TO FIND BEST CLUSTER GROUPS

groupedclusters = grouped.drop('Neighborhood', 1)

kclusters = np.arange(2,10)
results = {}
for size in kclusters:
    model = KMeans(n_clusters = size).fit(groupedclusters)
    predictions = model.predict(groupedclusters)
    results[size] = silhouette_score(groupedclusters, predictions)

best_size = max(results, key=results.get)
best_size
# Out:
# 9

# %%
# RUN K MEANS AND SEGMENT DATA

kclusters = best_size
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(groupedclusters)

# CHECK LABELS

kmeans.labels_[0:10]
# Out:
# array([6, 7, 2, 5, 2, 4, 5, 3, 3, 1], dtype=int32)

# %%
# MERGE TORONTO DATA WITH COORDINATE DATA AND GET CLUSTER LABELS
labels = pd.merge(Toronto_complete, grouped, on='Neighborhood', how='right')
labels.drop(labels[labels['Population2016']==0].index, inplace=True)
labels.drop(labels[labels['Population2016']==10].index, inplace=True)
labels.head()
# Out:
#   Postal Code  Population2016      Borough  \
# 0         M1S         37769.0  Scarborough
# 1         M8W         20674.0    Etobicoke
# 2         M3H         37011.0   North York
# 3         M2K         23852.0   North York
# 4         M5M         25975.0   North York
#
#                                         Neighborhood   Latitude  Longitude  \
# 0                               Agincourt, Agincourt  43.794200 -79.262029
# 1     Alderwood, Long Branch, Alderwood, Long Branch  43.602414 -79.543484
# 2  Bathurst Manor, Wilson Heights, Downsview Nort...  43.754328 -79.442259
# 3                   Bayview Village, Bayview Village  43.786947 -79.385975
# 4  Bedford Park, Lawrence Manor East, Bedford Par...  43.733283 -79.419750
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0          Noodle House      Sushi Restaurant   Japanese Restaurant
# 1      Sushi Restaurant   Japanese Restaurant      Ramen Restaurant
# 2      Sushi Restaurant   Japanese Restaurant      Ramen Restaurant
# 3   Japanese Restaurant      Sushi Restaurant      Ramen Restaurant
# 4      Sushi Restaurant   Japanese Restaurant      Ramen Restaurant
#
#   4th Most Common Venue  Japanese Restaurant  Noodle House  Ramen Restaurant  \
# 0      Ramen Restaurant             0.222222      0.444444          0.000000
# 1          Noodle House             0.500000      0.000000          0.000000
# 2          Noodle House             0.333333      0.000000          0.166667
# 3          Noodle House             0.600000      0.000000          0.200000
# 4          Noodle House             0.333333      0.000000          0.111111
#
#    Sushi Restaurant
# 0          0.333333
# 1          0.500000
# 2          0.500000
# 3          0.200000
# 4          0.555556

# %%
# ADD CLUSTERED LABELS

tablewithlabels = labels
tablewithlabels['Cluster Labels'] = kmeans.labels_

# MERGE TO ADD LAT LONG TO EACH NEIGHBORHOOD

tablewithlabels = pd.merge(labels, neighborhoods_venues_sorted, on='Neighborhood', how='left')

tablewithlabels.head()
# Out:
#   Postal Code  Population2016      Borough  \
# 0         M1S         37769.0  Scarborough
# 1         M8W         20674.0    Etobicoke
# 2         M3H         37011.0   North York
# 3         M2K         23852.0   North York
# 4         M5M         25975.0   North York
#
#                                         Neighborhood   Latitude  Longitude  \
# 0                               Agincourt, Agincourt  43.794200 -79.262029
# 1     Alderwood, Long Branch, Alderwood, Long Branch  43.602414 -79.543484
# 2  Bathurst Manor, Wilson Heights, Downsview Nort...  43.754328 -79.442259
# 3                   Bayview Village, Bayview Village  43.786947 -79.385975
# 4  Bedford Park, Lawrence Manor East, Bedford Par...  43.733283 -79.419750
#
#   1st Most Common Venue_x 2nd Most Common Venue_x 3rd Most Common Venue_x  \
# 0            Noodle House        Sushi Restaurant     Japanese Restaurant
# 1        Sushi Restaurant     Japanese Restaurant        Ramen Restaurant
# 2        Sushi Restaurant     Japanese Restaurant        Ramen Restaurant
# 3     Japanese Restaurant        Sushi Restaurant        Ramen Restaurant
# 4        Sushi Restaurant     Japanese Restaurant        Ramen Restaurant
#
#   4th Most Common Venue_x  Japanese Restaurant  Noodle House  \
# 0        Ramen Restaurant             0.222222      0.444444
# 1            Noodle House             0.500000      0.000000
# 2            Noodle House             0.333333      0.000000
# 3            Noodle House             0.600000      0.000000
# 4            Noodle House             0.333333      0.000000
#
#    Ramen Restaurant  Sushi Restaurant  Cluster Labels 1st Most Common Venue_y  \
# 0          0.000000          0.333333               6            Noodle House
# 1          0.000000          0.500000               7        Sushi Restaurant
# 2          0.166667          0.500000               2        Sushi Restaurant
# 3          0.200000          0.200000               5     Japanese Restaurant
# 4          0.111111          0.555556               2        Sushi Restaurant
#
#   2nd Most Common Venue_y 3rd Most Common Venue_y 4th Most Common Venue_y
# 0        Sushi Restaurant     Japanese Restaurant        Ramen Restaurant
# 1     Japanese Restaurant        Ramen Restaurant            Noodle House
# 2     Japanese Restaurant        Ramen Restaurant            Noodle House
# 3        Sushi Restaurant        Ramen Restaurant            Noodle House
# 4     Japanese Restaurant        Ramen Restaurant            Noodle House

# %%
# FIND VALUES FOR EACH OF THE CLUSTERS

# %%
cluster1 = tablewithlabels.loc[tablewithlabels['Cluster Labels'] == 0, tablewithlabels.columns[[3, 4] + list(range(5, tablewithlabels.shape[1]))]]
cluster1.shape
# Out:
# (3, 16)

# %%
cluster2 = tablewithlabels.loc[tablewithlabels['Cluster Labels'] == 1, tablewithlabels.columns[[3, 4] + list(range(5, tablewithlabels.shape[1]))]]
cluster2.shape
# Out:
# (13, 16)

# %%
cluster3 = tablewithlabels.loc[tablewithlabels['Cluster Labels'] == 2, tablewithlabels.columns[[3, 4] + list(range(5, tablewithlabels.shape[1]))]]
cluster3.shape
# Out:
# (7, 16)

# %%
cluster4 = tablewithlabels.loc[tablewithlabels['Cluster Labels'] == 3, tablewithlabels.columns[[3, 4] + list(range(5, tablewithlabels.shape[1]))]]
cluster4.shape
# Out:
# (15, 16)

# %%
cluster5 = tablewithlabels.loc[tablewithlabels['Cluster Labels'] == 4, tablewithlabels.columns[[3, 4] + list(range(5, tablewithlabels.shape[1]))]]
cluster5.shape
# Out:
# (8, 16)

# %%
cluster6 = tablewithlabels.loc[tablewithlabels['Cluster Labels'] == 5, tablewithlabels.columns[[3, 4] + list(range(5, tablewithlabels.shape[1]))]]
cluster6.shape
# Out:
# (15, 16)

# %%
# CLUSTER 4 AND 6 HAVE THE SAME DENSITY, SO THEY ARE BOTH OPTIMAL LOCATIONS WITH THESE VARIABLES

# %%
# FIND GEOGRAPHIC CENTRE OF EACH CLUSTER

cluster4coords = cluster4[['Latitude', 'Longitude']]
cluster4coords = list(cluster4coords.values) 
lat = []
long = []

for l in cluster4coords:
  lat.append(l[0])
  long.append(l[1])

blatitude4 = sum(lat)/len(lat)
blongitude4 = sum(long)/len(long)
print(blatitude4)
print(blongitude4)
# Out:
# 43.710583493333345
# -79.39145293333334

# %%
cluster6coords = cluster6[['Latitude', 'Longitude']]
cluster6coords = list(cluster6coords.values) 
lat = []
long = []

for l in cluster6coords:
  lat.append(l[0])
  long.append(l[1])

blatitude6 = sum(lat)/len(lat)
blongitude6 = sum(long)/len(long)
print(blatitude6)
print(blongitude6)
# Out:
# 43.70664769333334
# -79.38809083333332

# %%
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.1.0                |     pyhd3deb0d_0          64 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          98 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.1.0-pyhd3deb0d_0
#
#
#
# Downloading and Extracting Packages
# geopy-2.1.0          | 64 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# !pip install opencage
from opencage.geocoder import OpenCageGeocode
# Out:
# Collecting opencage
#   Downloading https://files.pythonhosted.org/packages/44/56/e912b950ab7b05902c08ebc3eb6c6e22f40ca2657194e04fc205a9d793e7/opencage-1.2.2-py3-none-any.whl
# Requirement already satisfied: pyopenssl>=0.15.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from opencage) (20.0.1)
# Collecting backoff>=1.10.0 (from opencage)
#   Downloading https://files.pythonhosted.org/packages/f0/32/c5dd4f4b0746e9ec05ace2a5045c1fc375ae67ee94355344ad6c7005fd87/backoff-1.10.0-py2.py3-none-any.whl
# Requirement already satisfied: Requests>=2.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from opencage) (2.25.0)
# Requirement already satisfied: six>=1.4.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from opencage) (1.15.0)
# Requirement already satisfied: cryptography>=3.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pyopenssl>=0.15.1->opencage) (3.3.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Requests>=2.2.0->opencage) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Requests>=2.2.0->opencage) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Requests>=2.2.0->opencage) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from Requests>=2.2.0->opencage) (2.10)
# Requirement already satisfied: cffi>=1.12 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from cryptography>=3.2->pyopenssl>=0.15.1->opencage) (1.14.4)
# Requirement already satisfied: pycparser in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from cffi>=1.12->cryptography>=3.2->pyopenssl>=0.15.1->opencage) (2.20)
# Installing collected packages: backoff, opencage
# Successfully installed backoff-1.10.0 opencage-1.2.2

# %%
from pprint import pprint

# %%
# Finding the best location on cluster 4 using opencage
key = 'a3c042ed8fe641e4abe8a2ae595e08a7'
geocoder = OpenCageGeocode(key)

results = geocoder.reverse_geocode(43.710583493333345, -79.39145293333334)
pprint(results)
# Out:
# [{'annotations': {'DMS': {'lat': "43° 42' 38.34396'' N",
#                           'lng': "79° 23' 29.12172'' W"},
#                   'MGRS': '17TPJ2959240993',
#                   'Maidenhead': 'FN03hr30an',
#                   'Mercator': {'x': -8837812.747, 'y': 5391237.11},
#                   'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=56495093#map=17/43.71065/-79.39142',
#                           'note_url': 'https://www.openstreetmap.org/note/new#map=17/43.71065/-79.39142&layers=N',
#                           'url': 'https://www.openstreetmap.org/?mlat=43.71065&mlon=-79.39142#map=17/43.71065/-79.39142'},
#                   'UN_M49': {'regions': {'AMERICAS': '019',
#                                          'CA': '124',
#                                          'NORTHERN_AMERICA': '021',
#                                          'WORLD': '001'},
#                              'statistical_groupings': ['MEDC']},
#                   'callingcode': 1,
#                   'currency': {'alternate_symbols': ['C$', 'CAD$'],
#                                'decimal_mark': '.',
#                                'disambiguate_symbol': 'C$',
#                                'html_entity': '$',
#                                'iso_code': 'CAD',
#                                'iso_numeric': '124',
#                                'name': 'Canadian Dollar',
#                                'smallest_denomination': 5,
#                                'subunit': 'Cent',
#                                'subunit_to_unit': 100,
#                                'symbol': '$',
#                                'symbol_first': 1,
#                                'thousands_separator': ','},
#                   'flag': '🇨🇦',
#                   'geohash': 'dpz89mkbvzbw4rpmkzuy',
#                   'qibla': 54.57,
#                   'roadinfo': {'drive_on': 'right',
#                                'road': 'Mount Pleasant Road',
#                                'speed_in': 'km/h'},
#                   'sun': {'rise': {'apparent': 1614168120,
#                                    'astronomical': 1614162420,
#                                    'civil': 1614166440,
#                                    'nautical': 1614164400},
#                           'set': {'apparent': 1614207600,
#                                   'astronomical': 1614126900,
#                                   'civil': 1614209280,
#                                   'nautical': 1614124920}},
#                   'timezone': {'name': 'America/Toronto',
#                                'now_in_dst': 0,
#                                'offset_sec': -18000,
#                                'offset_string': '-0500',
#                                'short_name': 'EST'},
#                   'what3words': {'words': 'folk.strut.think'}},
#   'bounds': {'northeast': {'lat': 43.7108941, 'lng': -79.3912928},
#              'southwest': {'lat': 43.710533, 'lng': -79.3915995}},
#   'components': {'ISO_3166-1_alpha-2': 'CA',
#                  'ISO_3166-1_alpha-3': 'CAN',
#                  '_category': 'building',
#                  '_type': 'building',
#                  'city': 'Old Toronto',
#                  'continent': 'North America',
#                  'country': 'Canada',
#                  'country_code': 'ca',
#                  'house_number': '890',
#                  'neighbourhood': 'Davisville',
#                  'postcode': 'M4P 1K5',
#                  'quarter': 'Don Valley West',
#                  'road': 'Mount Pleasant Road',
#                  'state': 'Ontario',
#                  'state_code': 'ON',
#                  'state_district': 'Golden Horseshoe'},
#   'confidence': 10,
#   'formatted': '890 Mount Pleasant Road, Old Toronto, ON M4P 1K5, Canada',
#   'geometry': {'lat': 43.7106511, 'lng': -79.3914227}}]

# %%
# Best location name on cluster 4
popstr = df3[df3['Postal Code'].str.contains('M4P')]

def str_join(*args):
    return ''.join(map(str, args))

popstr = str_join('Best Location: ', popstr['Neighborhood'].values, ' in ', popstr['Borough'].values)

print(popstr)
# Out:
# Best Location: ['Davisville North, Davisville North'] in ['Central Toronto']

# %%
# Finding the best location on cluster 6 using opencage (input coordinates of cluster 6)
key = 'a3c042ed8fe641e4abe8a2ae595e08a7'
geocoder = OpenCageGeocode(key)
results6 = geocoder.reverse_geocode(43.70664769333334, -79.38809083333332)
pprint(results6)
# Out:
# [{'annotations': {'DMS': {'lat': "43° 42' 23.97168'' N",
#                           'lng': "79° 23' 17.36088'' W"},
#                   'MGRS': '17TPJ2986340555',
#                   'Maidenhead': 'FN03hq39ko',
#                   'Mercator': {'x': -8837449.077, 'y': 5390624.455},
#                   'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=401259621#map=16/43.70666/-79.38816',
#                           'note_url': 'https://www.openstreetmap.org/note/new#map=16/43.70666/-79.38816&layers=N',
#                           'url': 'https://www.openstreetmap.org/?mlat=43.70666&mlon=-79.38816#map=16/43.70666/-79.38816'},
#                   'UN_M49': {'regions': {'AMERICAS': '019',
#                                          'CA': '124',
#                                          'NORTHERN_AMERICA': '021',
#                                          'WORLD': '001'},
#                              'statistical_groupings': ['MEDC']},
#                   'callingcode': 1,
#                   'currency': {'alternate_symbols': ['C$', 'CAD$'],
#                                'decimal_mark': '.',
#                                'disambiguate_symbol': 'C$',
#                                'html_entity': '$',
#                                'iso_code': 'CAD',
#                                'iso_numeric': '124',
#                                'name': 'Canadian Dollar',
#                                'smallest_denomination': 5,
#                                'subunit': 'Cent',
#                                'subunit_to_unit': 100,
#                                'symbol': '$',
#                                'symbol_first': 1,
#                                'thousands_separator': ','},
#                   'flag': '🇨🇦',
#                   'geohash': 'dpz89kx39zswczu5vz3f',
#                   'qibla': 54.57,
#                   'roadinfo': {'drive_on': 'right',
#                                'road': 'Taunton Road',
#                                'speed_in': 'km/h'},
#                   'sun': {'rise': {'apparent': 1614168120,
#                                    'astronomical': 1614162420,
#                                    'civil': 1614166440,
#                                    'nautical': 1614164400},
#                           'set': {'apparent': 1614207600,
#                                   'astronomical': 1614126900,
#                                   'civil': 1614209280,
#                                   'nautical': 1614124920}},
#                   'timezone': {'name': 'America/Toronto',
#                                'now_in_dst': 0,
#                                'offset_sec': -18000,
#                                'offset_string': '-0500',
#                                'short_name': 'EST'},
#                   'what3words': {'words': 'cycle.meals.verdict'}},
#   'bounds': {'northeast': {'lat': 43.7067088, 'lng': -79.3881058},
#              'southwest': {'lat': 43.7066088, 'lng': -79.3882058}},
#   'components': {'ISO_3166-1_alpha-2': 'CA',
#                  'ISO_3166-1_alpha-3': 'CAN',
#                  '_category': 'building',
#                  '_type': 'building',
#                  'city': 'Old Toronto',
#                  'continent': 'North America',
#                  'country': 'Canada',
#                  'country_code': 'ca',
#                  'house_number': '22',
#                  'neighbourhood': 'Davisville',
#                  'postcode': 'M4S 2P2',
#                  'quarter': 'Don Valley West',
#                  'road': 'Taunton Road',
#                  'state': 'Ontario',
#                  'state_code': 'ON',
#                  'state_district': 'Golden Horseshoe'},
#   'confidence': 10,
#   'formatted': '22 Taunton Road, Old Toronto, ON M4S 2P2, Canada',
#   'geometry': {'lat': 43.7066588, 'lng': -79.3881558}}]

# %%
# Best location name on cluster 6
popstr6 = df3[df3['Postal Code'].str.contains('M4S')]

def str_join(*args):
    return ''.join(map(str, args))

popstr6 = str_join('Best Location: ', popstr6['Neighborhood'].values, ' in ', popstr6['Borough'].values)

print(popstr6)
# Out:
# Best Location: ['Davisville, Davisville'] in ['Central Toronto']

# %%
# USING GEOPY GEOCODERS

address = 'Toronto, ON'

geolocator = Nominatim(user_agent="http")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print("Toronto's Geographical Coordinates: {}, {}".format(latitude, longitude))
# Out:
# Toronto's Geographical Coordinates: 43.6534817, -79.3839347

# %%
# Using Folium to show the Location of Cluster 4

map_clusters4 = folium.Map(location=[latitude, longitude], zoom_start=12)

# Colours

x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Adding markers
markers_colors = []
for lat, lon, poi, cluster in zip(tablewithlabels['Latitude'], tablewithlabels['Longitude'], tablewithlabels['Neighborhood'], tablewithlabels['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters4)
    
folium.CircleMarker([blatitude4, blongitude4],
                    radius=50,
                    popup='Toronto',
                    color='red',
                    ).add_to(map_clusters4)

map_clusters4.save('map_clusters4.html')
map_clusters4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Using Folium to show the Location of Cluster 6

map_clusters6 = folium.Map(location=[latitude, longitude], zoom_start=12)

# Colours

x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Adding markers
markers_colors = []
for lat, lon, poi, cluster in zip(tablewithlabels['Latitude'], tablewithlabels['Longitude'], tablewithlabels['Neighborhood'], tablewithlabels['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters6)
    
folium.CircleMarker([blatitude6, blongitude6],
                    radius=50,
                    popup='Toronto',
                    color='red',
                    ).add_to(map_clusters6)

map_clusters6.save('map_clusters6.html')
map_clusters6
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Observations and Conclusion

# %% [markdown]
# As it was expected, the ideal location to open a Japanese restaurant is in the city center of Toronto. Considering the reported results, the cluesters 4 and 6 have the maximum density, so in theory the ideal place to open a Japanese restaurant would be within this 2 clusters that are both located in Central Toronto.
# By analysing the exact locations of these clusters, it is possible to see that the cluster 4 is located in a position a bit far away from other restaurants. On the other hand, the cluster 6 is closer to other restaurants. So based on this model and on the assumptions taken, we assume that the ideal location for opening a Japanese restaurant is in Davisville in Central Toronto, which is the location of Cluster's 6 center.

# %% [markdown]
# Please take a look to the following maps, as these support our conclusions.
# The Folium interactive maps are not displayed in this notebook as it is a not trusted properly by GitHub. However, it is possible to see a screenshot of each map on my GitHub repository: https://github.com/hairtractive/Coursera_Capstone.
# The first map "Map Cluster 4" displays the center location of cluster 4 and the second map "Map Cluster 6" displays the center location of cluster 6. Finally, the third map, displays the neighborhoods of the cluster 6.
#
# Please check the maps here:
# - First map "Map Cluster 4": https://github.com/hairtractive/Coursera_Capstone/blob/main/Map%20Cluster%204.png
# - Second map "Map Cluster 6": https://github.com/hairtractive/Coursera_Capstone/blob/main/Map%20Cluster%206.png
# - Third map "Map Cluster 6 Neighborhoods": https://github.com/hairtractive/Coursera_Capstone/blob/main/Map%20Cluster%206%20Neighborhoods.png

# %% [markdown]
# # Thank you!

# %% [markdown]
# Miguel Silva
